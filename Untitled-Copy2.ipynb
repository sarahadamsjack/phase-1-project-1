# %% [markdown]
# <img src=images/film3.jpg width = "1500" height = "4000">

# %% [markdown]
# # Its Movie Time!!

# %% [markdown]
# #### _By: Sarah, Brendan and Ben_
#
# - - -

# %% [markdown]
# ## Project Overview

# %% [markdown]
# One of the most important in steps in any movie making is pre-production. These stage includes all the
#
#
#
#
# - note to group: if there is time midweek we will look into what studios did the best
# - note to group: the numbers data is NOT adjusted for inflation
#
# **ASK JELLY/JULIAN FOR DATA DICTIONARY: HOW DOES THE NUMBERS CALCULATE WORLDWIDE? ALSO, SOME MOVIE STUDIOS ARE NOT LOCATED IN THE US, WHAT DOES DOMESTIC MEAN BY THAT?

# %%
import pandas as pd
import sqlite3 as sql
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# !ls Data
# Out:
# ls: Data: No such file or directory

# %%
# Reading all the datasets that will be used for the project
tn_df = pd.read_csv('tn.movie_budgets.csv.gz')
tn_df = tn_df.rename(columns = {'title': 'movie'})
database = "im.db"
connection = sql.connect(database)

# %%
# connecting sqlite3 cursor
query = ''' SELECT * FROM movie_basics'''
sql_df = pd.read_sql_query(query, connection)
sql_df = sql_df.rename(columns = {'primary_title': 'movie'})

# %% [markdown]
# ### Data Cleaning And Preparation.

# %%
# Starting cleaning the tn_df file by removing all the comma's and $ and make them integers which would be much
# much easier for data manipulation
tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
tn_df['production_budget'] = tn_df['production_budget'].str[1:]
tn_df['production_budget'] = tn_df['production_budget'].str.replace(',', '').astype(np.int64)
tn_df['domestic_gross'] = tn_df['domestic_gross'].str[1:]
tn_df['domestic_gross'] = tn_df['domestic_gross'].str.replace(',', '').astype(np.int64)
tn_df['worldwide_gross'] = tn_df['worldwide_gross'].str[1:]
tn_df['worldwide_gross'] = tn_df['worldwide_gross'].str.replace(',', '').astype(np.int64)

# %%
# Now we start filtering our data for movies production budget under $5,000.000
prod_budget = tn_df[tn_df.production_budget < 5000000].index
tn_df.drop(prod_budget, inplace = True)
ww_gross = tn_df[tn_df.worldwide_gross < 5000000].index
tn_df.drop(ww_gross, inplace = True)

tn_df.set_index('movie')

#note to group: we will not filter for the production budget, we will look at all movies 
#note to ben: beautiful filtering!!! thank you so much <3
# Out:
#                                              id  release_date  \
# movie
# Avatar                                        1  Dec 18, 2009
# Pirates of the Caribbean: On Stranger Tides   2  May 20, 2011
# Dark Phoenix                                  3   Jun 7, 2019
# Avengers: Age of Ultron                       4   May 1, 2015
# Star Wars Ep. VIII: The Last Jedi             5  Dec 15, 2017
# ...                                          ..           ...
# Rabbit Hole                                  52  Dec 17, 2010
# Paterson                                     54  Dec 28, 2016
# The Machinist                                57  Oct 22, 2004
# Tucker & Dale vs. Evil                       69  Sep 30, 2011
# Mientras duermes                             82  Oct 26, 2012
#
#                                              production_budget  \
# movie
# Avatar                                               425000000
# Pirates of the Caribbean: On Stranger Tides          410600000
# Dark Phoenix                                         350000000
# Avengers: Age of Ultron                              330600000
# Star Wars Ep. VIII: The Last Jedi                    317000000
# ...                                                        ...
# Rabbit Hole                                            5000000
# Paterson                                               5000000
# The Machinist                                          5000000
# Tucker & Dale vs. Evil                                 5000000
# Mientras duermes                                       5000000
#
#                                              domestic_gross  worldwide_gross
# movie
# Avatar                                            760507625       2776345279
# Pirates of the Caribbean: On Stranger Tides       241063875       1045663875
# Dark Phoenix                                       42762350        149762350
# Avengers: Age of Ultron                           459005868       1403013963
# Star Wars Ep. VIII: The Last Jedi                 620181382       1316721747
# ...                                                     ...              ...
# Rabbit Hole                                         2229058          6205034
# Paterson                                            2141423         10727536
# The Machinist                                       1082044          8655397
# Tucker & Dale vs. Evil                               223838          5476793
# Mientras duermes                                          0          9109597
#
# [3823 rows x 5 columns]

# %%
# We will now starting on creating our master dataset by combining both datasets
master_data = tn_df.merge(sql_df, on = 'movie').drop\
(columns = ['original_title', 'start_year', 'id'])

# %%
# We will be removing any duplicates from our dataset
master_data = master_data.drop_duplicates(subset  = 'movie').set_index('movie_id')
master_data.tail(10)
# Out:
#            release_date                                       movie  \
# movie_id
# tt1082807  Mar 17, 2017                        The Belko Experiment
# tt3444696  Mar 11, 2016                           The Perfect Match
# tt5124556  Apr 27, 2001                                The Forsaken
# tt8632862  Sep 21, 2018                             Fahrenheit 11/9
# tt1529567  May 28, 2010  Sea Rex 3D: Journey to a Prehistoric World
# tt3216348   Dec 2, 2016                                   Incarnate
# tt3566920   Mar 4, 2016                  The Other Side of the Door
# tt1216491  Oct 10, 2014                          Kill the Messenger
# tt0935075  Dec 17, 2010                                 Rabbit Hole
# tt5247022  Dec 28, 2016                                    Paterson
#
#            production_budget  domestic_gross  worldwide_gross  \
# movie_id
# tt1082807            5000000        10166820         11792942
# tt3444696            5000000         9669521         10182050
# tt5124556            5000000         6755271          6755271
# tt8632862            5000000         6352306          6653715
# tt1529567            5000000         6096582         16515203
# tt3216348            5000000         4799774          9371036
# tt3566920            5000000         3000342         12905107
# tt1216491            5000000         2450846          6656705
# tt0935075            5000000         2229058          6205034
# tt5247022            5000000         2141423         10727536
#
#            runtime_minutes                        genres
# movie_id
# tt1082807             89.0               Horror,Thriller
# tt3444696             87.0  Biography,Documentary,Family
# tt5124556             86.0         Drama,Horror,Thriller
# tt8632862            128.0                   Documentary
# tt1529567             41.0                   Documentary
# tt3216348             91.0               Horror,Thriller
# tt3566920             90.0                         Drama
# tt1216491            112.0         Biography,Crime,Drama
# tt0935075             91.0                         Drama
# tt5247022            118.0          Comedy,Drama,Romance

# %%
# We will create a new column for movies released month to help with manipulation of our data
master_data['release_month'] = master_data['release_date'].str[:3]

# %%
# The next step is to drop all the NaN and get our data ready for analysis
master_data.dropna(inplace = True)

# %%
#creating two ROIs columns: worldwide ROI & domestic ROI
master_data['domestic_ROI_perc'] = (master_data['domestic_gross'] - master_data['production_budget']) / master_data['production_budget'] * 100

master_data['worldwide_ROI_perc'] =(master_data['worldwide_gross'] - master_data['production_budget']) / master_data['production_budget'] * 100

# %%
master_data
# Out:
#            release_date                                        movie  \
# movie_id
# tt1775309  Dec 18, 2009                                       Avatar
# tt1298650  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# tt6565702   Jun 7, 2019                                 Dark Phoenix
# tt2395427   May 1, 2015                      Avengers: Age of Ultron
# tt4154756  Apr 27, 2018                       Avengers: Infinity War
# ...                 ...                                          ...
# tt3216348   Dec 2, 2016                                    Incarnate
# tt3566920   Mar 4, 2016                   The Other Side of the Door
# tt1216491  Oct 10, 2014                           Kill the Messenger
# tt0935075  Dec 17, 2010                                  Rabbit Hole
# tt5247022  Dec 28, 2016                                     Paterson
#
#            production_budget  domestic_gross  worldwide_gross  \
# movie_id
# tt1775309          425000000       760507625       2776345279
# tt1298650          410600000       241063875       1045663875
# tt6565702          350000000        42762350        149762350
# tt2395427          330600000       459005868       1403013963
# tt4154756          300000000       678815482       2048134200
# ...                      ...             ...              ...
# tt3216348            5000000         4799774          9371036
# tt3566920            5000000         3000342         12905107
# tt1216491            5000000         2450846          6656705
# tt0935075            5000000         2229058          6205034
# tt5247022            5000000         2141423         10727536
#
#            runtime_minutes                    genres release_month  \
# movie_id
# tt1775309             93.0                    Horror           Dec
# tt1298650            136.0  Action,Adventure,Fantasy           May
# tt6565702            113.0   Action,Adventure,Sci-Fi           Jun
# tt2395427            141.0   Action,Adventure,Sci-Fi           May
# tt4154756            149.0   Action,Adventure,Sci-Fi           Apr
# ...                    ...                       ...           ...
# tt3216348             91.0           Horror,Thriller           Dec
# tt3566920             90.0                     Drama           Mar
# tt1216491            112.0     Biography,Crime,Drama           Oct
# tt0935075             91.0                     Drama           Dec
# tt5247022            118.0      Comedy,Drama,Romance           Dec
#
#            domestic_ROI_perc  worldwide_ROI_perc
# movie_id
# tt1775309          78.942971          553.257713
# tt1298650         -41.289850          154.667286
# tt6565702         -87.782186          -57.210757
# tt2395427          38.840250          324.384139
# tt4154756         126.271827          582.711400
# ...                      ...                 ...
# tt3216348          -4.004520           87.420720
# tt3566920         -39.993160          158.102140
# tt1216491         -50.983080           33.134100
# tt0935075         -55.418840           24.100680
# tt5247022         -57.171540          114.550720
#
# [1404 rows x 10 columns]

# %%
master_data = master_data.drop_duplicates(subset  = 'movie').set_index('movie')

# %%
mdmultigenres = master_data['genres'].str.split(',', expand=True)

# %%
mdmultigenres['Horror'] = mdmultigenres[0].str.contains('Horror').replace(to_replace = True, value = 'Horror').replace(to_replace = False, value = '')

# %%
genre = master_data['genres'].to_frame().join(master_data['worldwide_ROI_perc'])
genre
# Out:
#                                                                genres  \
# movie
# Avatar                                                         Horror
# Pirates of the Caribbean: On Stranger Tides  Action,Adventure,Fantasy
# Dark Phoenix                                  Action,Adventure,Sci-Fi
# Avengers: Age of Ultron                       Action,Adventure,Sci-Fi
# Avengers: Infinity War                        Action,Adventure,Sci-Fi
# ...                                                               ...
# Incarnate                                             Horror,Thriller
# The Other Side of the Door                                      Drama
# Kill the Messenger                              Biography,Crime,Drama
# Rabbit Hole                                                     Drama
# Paterson                                         Comedy,Drama,Romance
#
#                                              worldwide_ROI_perc
# movie
# Avatar                                               553.257713
# Pirates of the Caribbean: On Stranger Tides          154.667286
# Dark Phoenix                                         -57.210757
# Avengers: Age of Ultron                              324.384139
# Avengers: Infinity War                               582.711400
# ...                                                         ...
# Incarnate                                             87.420720
# The Other Side of the Door                           158.102140
# Kill the Messenger                                    33.134100
# Rabbit Hole                                           24.100680
# Paterson                                             114.550720
#
# [1404 rows x 2 columns]

# %%
genre.head()
# Out:
#                                                                genres  \
# movie
# Avatar                                                         Horror
# Pirates of the Caribbean: On Stranger Tides  Action,Adventure,Fantasy
# Dark Phoenix                                  Action,Adventure,Sci-Fi
# Avengers: Age of Ultron                       Action,Adventure,Sci-Fi
# Avengers: Infinity War                        Action,Adventure,Sci-Fi
#
#                                              worldwide_ROI_perc
# movie
# Avatar                                               553.257713
# Pirates of the Caribbean: On Stranger Tides          154.667286
# Dark Phoenix                                         -57.210757
# Avengers: Age of Ultron                              324.384139
# Avengers: Infinity War                               582.711400

# %%
genre.loc['Avatar', 'genres'] = 'Action,Adventure,Sci-Fi'

# %%
genre.loc['Avatar', 'genres']
# Out:
# 'Action,Adventure,Sci-Fi'

# %%
Action = genre[(genre.genres.str.contains('Action'))]
Action['worldwide_ROI_perc'].median()
# Out:
# 138.0179670833333

# %%
Action['worldwide_ROI_perc'].describe()
# Out:
# count     408.000000
# mean      206.946935
# std       276.696601
# min       -84.145437
# 25%        32.752905
# 50%       138.017967
# 75%       294.399096
# max      3001.627558
# Name: worldwide_ROI_perc, dtype: float64

# %%
Action = genre[(genre.genres.str.contains('Action'))]
Adventure = genre[(genre.genres.str.contains('Adventure'))]
Animation = genre[(genre.genres.str.contains('Animation'))]
Biography = genre[(genre.genres.str.contains('Biography'))]
Comedy = genre[(genre.genres.str.contains('Comedy'))]
Crime = genre[(genre.genres.str.contains('Crime'))]
Drama = genre[(genre.genres.str.contains('Drama'))]
Fantasy = genre[(genre.genres.str.contains('Fantasy'))]
Horror = genre[(genre.genres.str.contains('Horror'))]
Mystery = genre[(genre.genres.str.contains('Mystery'))]
Music = genre[(genre.genres.str.contains('Music'))]
Musical = genre[(genre.genres.str.contains('Musical'))]
Romance = genre[(genre.genres.str.contains('Romance'))]
SciFi = genre[(genre.genres.str.contains('Sci-Fi'))]
Thriller = genre[(genre.genres.str.contains('Thriller'))]
War = genre[(genre.genres.str.contains('War'))]

# %%
Action.head()
# Out:
#                                                                genres  \
# movie
# Avatar                                        Action,Adventure,Sci-Fi
# Pirates of the Caribbean: On Stranger Tides  Action,Adventure,Fantasy
# Dark Phoenix                                  Action,Adventure,Sci-Fi
# Avengers: Age of Ultron                       Action,Adventure,Sci-Fi
# Avengers: Infinity War                        Action,Adventure,Sci-Fi
#
#                                              worldwide_ROI_perc
# movie
# Avatar                                               553.257713
# Pirates of the Caribbean: On Stranger Tides          154.667286
# Dark Phoenix                                         -57.210757
# Avengers: Age of Ultron                              324.384139
# Avengers: Infinity War                               582.711400

# %%
Action.describe()
# Out:
#        worldwide_ROI_perc
# count          408.000000
# mean           206.946935
# std            276.696601
# min            -84.145437
# 25%             32.752905
# 50%            138.017967
# 75%            294.399096
# max           3001.627558

# %%
mdmultigenres[0].value_counts()
# Out:
# Action         407
# Comedy         246
# Drama          245
# Adventure      159
# Biography      114
# Crime           67
# Horror          62
# Documentary     59
# Animation       12
# Thriller        11
# Sci-Fi           6
# Fantasy          5
# Mystery          4
# Music            2
# Musical          2
# Romance          2
# War              1
# Name: 0, dtype: int64

# %%
def genre_finder(mdmultigenres):
    if mdmultigenres == 'Action':
        return print ('Action')
    elif mdmultigenres == 'Comedy':
        return print ('Comedy')
    elif mdmultigenres == 'Drama':
        return print ('Drama')
    elif mdmultigenres == 'Adventure':
        return print ('Adventure')
    elif mdmultigenres == 'Biography':
        return print ('Biography')
    elif mdmultigenres == 'Crime':
        return print ('Crime')
    elif mdmultigenres == 'Horror':
        return print ('Horror')
    elif mdmultigenres == 'Documentary':
        return print ('Documentary')
    elif mdmultigenres == 'Animation':
        return print ('Animation')
    elif mdmultigenres == 'Thriller':
        return print ('Thriller')
    elif mdmultigenres == 'Sci-Fi':
        return print ('Sci-Fi')
    elif mdmultigenres == 'Fantasy':
        return print ('Fantasy')
    elif mdmultigenres == 'Mystery':
        return print ('Mystery')
    elif mdmultigenres == 'Musical':
        return print ('Musical')
    elif mdmultigenres == 'Romance':
        return print ('Romance')
    elif mdmultigenres == 'Music':
        return print ('Music')
    elif mdmultigenres == 'War':
        return print ('War')
    else:
        return print == 'N/A'

# %%
genre_dic = {
'Action': Action['worldwide_ROI_perc'].median(),
'Adventure': Adventure['worldwide_ROI_perc'].median(),
'Animation': Animation['worldwide_ROI_perc'].median(),
'Biography': Biography['worldwide_ROI_perc'].median(),
'Comedy' : Comedy['worldwide_ROI_perc'].median(),
'Crime' : Crime['worldwide_ROI_perc'].median(),
'Drama' : Drama['worldwide_ROI_perc'].median(),
'Fantasy' : Fantasy['worldwide_ROI_perc'].median(),
'Horror' : Horror['worldwide_ROI_perc'].median(),
'Mystery' : Mystery['worldwide_ROI_perc'].median(),
'Music' : Music['worldwide_ROI_perc'].median(),
'Musical' : Musical['worldwide_ROI_perc'].median(),
'Romance' : Romance['worldwide_ROI_perc'].median(),
'SciFi' : SciFi['worldwide_ROI_perc'].median(),
'Thriller' : Thriller['worldwide_ROI_perc'].median(),
'War' : War['worldwide_ROI_perc'].median()
}

genre_dic
# Out:
# {'Action': 138.0179670833333,
#  'Adventure': 169.09212505760368,
#  'Animation': 199.6219057099957,
#  'Biography': 124.48340833333333,
#  'Comedy': 161.12426126126127,
#  'Crime': 102.4848325,
#  'Drama': 123.14857029411765,
#  'Fantasy': 118.28200476190476,
#  'Horror': 218.56252681818182,
#  'Mystery': 194.12664025641027,
#  'Music': 154.53043583333334,
#  'Musical': 90.82392,
#  'Romance': 135.92804266666667,
#  'SciFi': 195.06455384615384,
#  'Thriller': 147.45423493506496,
#  'War': 152.59669304924242}

# %%
genre_dfs = [Action, Adventure, Animation, Biography, Comedy, Crime, Drama, Fantasy, Horror, Mystery, Music, Musical, Romance, SciFi, Thriller, War]

# %%
combined_genres = pd.concat(genre_dfs)

# %%
combined_genres.head()
# Out:
#                                                                genres  \
# movie
# Avatar                                        Action,Adventure,Sci-Fi
# Pirates of the Caribbean: On Stranger Tides  Action,Adventure,Fantasy
# Dark Phoenix                                  Action,Adventure,Sci-Fi
# Avengers: Age of Ultron                       Action,Adventure,Sci-Fi
# Avengers: Infinity War                        Action,Adventure,Sci-Fi
#
#                                              worldwide_ROI_perc
# movie
# Avatar                                               553.257713
# Pirates of the Caribbean: On Stranger Tides          154.667286
# Dark Phoenix                                         -57.210757
# Avengers: Age of Ultron                              324.384139
# Avengers: Infinity War                               582.711400

# %%
Action_and_Adventure_joined_genres = Action.join(Adventure, how = 'outer', lsuffix='Action', rsuffix = 'Adventure')

# %%
Action_and_Adventure_joined_genres.head()
# Out:
#                         genresAction  worldwide_ROI_percAction  \
# movie
# 12 Strong       Action,Drama,History                103.195366
# 127 Hours                        NaN                       NaN
# 2 Guns           Action,Comedy,Crime                117.201664
# 21 Jump Street   Action,Comedy,Crime                382.886736
# 22 Jump Street   Action,Comedy,Crime                562.667752
#
#                           genresAdventure  worldwide_ROI_percAdventure
# movie
# 12 Strong                             NaN                          NaN
# 127 Hours       Adventure,Biography,Drama                   234.539839
# 2 Guns                                NaN                          NaN
# 21 Jump Street                        NaN                          NaN
# 22 Jump Street                        NaN                          NaN

# %%
Action_median = Action['worldwide_ROI_perc'].median()
Adventure_median = Adventure['worldwide_ROI_perc'].median()
Animation_median = Animation['worldwide_ROI_perc'].median()
Biography_median = Biography['worldwide_ROI_perc'].median()
Comedy_median = Comedy['worldwide_ROI_perc'].median()
Crime_median = Crime['worldwide_ROI_perc'].median()
Drama_median = Drama['worldwide_ROI_perc'].median()
Fantasy_median = Fantasy['worldwide_ROI_perc'].median()
Horror_median = Horror['worldwide_ROI_perc'].median()
Music_median = Music['worldwide_ROI_perc'].median()
Musical_median = Musical['worldwide_ROI_perc'].median()
Mystery_median = Mystery['worldwide_ROI_perc'].median()
Romance_median = Romance['worldwide_ROI_perc'].median()
SciFi_median = SciFi['worldwide_ROI_perc'].median()
Thriller_median = Thriller['worldwide_ROI_perc'].median()
War_median = War['worldwide_ROI_perc'].median()

# %%
genre_df_medians = pd.DataFrame([['Action', Action_median], ['Adventure', Adventure_median], ['Animation', Animation_median], ['Biography', Biography_median], ['Comedy', Comedy_median], ['Crime', Crime_median], ['Drama', Drama_median], ['Fantasy', Fantasy_median], ['Horror', Horror_median], ['Music', Music_median], ['Musical', Musical_median], ['Mystery', Mystery_median], ['Romance', Romance_median], ['SciFi', SciFi_median], ['Thriller', Thriller_median], ['War', War_median]], columns=['genre', 'worldwide_ROI_perc'])

# %%
genre_df_medians.head()
# Out:
#        genre  worldwide_ROI_perc
# 0     Action          138.017967
# 1  Adventure          169.092125
# 2  Animation          199.621906
# 3  Biography          124.483408
# 4     Comedy          161.124261

# %%
genre_df_medians
# Out:
#         genre  worldwide_ROI_perc
# 0      Action          138.017967
# 1   Adventure          169.092125
# 2   Animation          199.621906
# 3   Biography          124.483408
# 4      Comedy          161.124261
# 5       Crime          102.484832
# 6       Drama          123.148570
# 7     Fantasy          118.282005
# 8      Horror          218.562527
# 9       Music          154.530436
# 10    Musical           90.823920
# 11    Mystery          194.126640
# 12    Romance          135.928043
# 13      SciFi          195.064554
# 14   Thriller          147.454235
# 15        War          152.596693

# %%
top5_genre_ROI = genre_df_medians.sort_values(by='worldwide_ROI_perc',ascending=False).head()

# %%
top5_genre_ROI
# Out:
#         genre  worldwide_ROI_perc
# 8      Horror          218.562527
# 2   Animation          199.621906
# 13      SciFi          195.064554
# 11    Mystery          194.126640
# 1   Adventure          169.092125

# %%
#graph 1: relationship between worldwide ROI and genre 
fig, ax = plt.subplots(figsize=(20, 10))


#setting x and y variables 
y1 = genre_df_medians['worldwide_ROI_perc']
x1 = genre_df_medians['genre']


#graphing variables
ax = sns.barplot(x=x1, y=y1, data=genre_df_medians)


#setting lables and titles
ax.set_title("Median Worldwide ROI in Percentanges for Films by Genre")
ax.set_ylabel("Worldwide ROI in Percentage")
ax.set_xlabel("Genre")

#Notes: The genres Fantasy, Music, Musical, Mystery, and War all have sample sizes lower than 5 and should be discounted.
#Notes: There are some overlaps between the genres because some movies had multiple genre classifications such as Crime/Drama.
#Notes: Action, Comedy, Drama, Adventure, and Biography had the largest value counts with 407, 246, 245, 159, and 114, respectively.
#Notes: Highest Worldwide ROI in descending order was Horror, Animation, SciFi, Mystery, and Adventure with 218.56, 199.62, 195.06, 194.13, and 169.09, respectively


#we can also use median as the estimator by doing this:
#from numpy import median
#y = master_data['domestic_ROI_perc']
#x = master_data['release_month']

#ax = sns.barplot(x=x, y=y, data=genre_df_medians, estimator=median).set(title="Median Worldwide ROI in Percentanges for Films by Genre")

#ax.set_xlabel("Genre")
#ax.set_ylabel("Worldwide ROI in Percentages")
# Out:
# Text(0.5, 0, 'Genre')

# %%
#graph 1: Highest worldwide ROI by genre 
fig, ax = plt.subplots(figsize=(10, 10))


#setting x and y variables 
y1 = top5_genre_ROI['worldwide_ROI_perc']
x1 = top5_genre_ROI['genre']


#graphing variables
ax = sns.barplot(x=x1, y=y1, data=top5_genre_ROI)


#setting lables and titles
ax.set_title("Median Worldwide ROI in Percentanges for Films by Genre")
ax.set_ylabel("Worldwide ROI in Percentage")
ax.set_xlabel("Genre")

#Notes: The genres Fantasy, Music, Musical, Mystery, and War all have sample sizes lower than 5 and should be discounted.
#Notes: There are some overlaps between the genres because some movies had multiple genre classifications such as Crime/Drama.
#Notes: Action, Comedy, Drama, Adventure, and Biography had the largest value counts with 407, 246, 245, 159, and 114, respectively.
#Notes: Highest Worldwide ROI in descending order was Horror, Animation, SciFi, Mystery, and Adventure with 218.56, 199.62, 195.06, 194.13, and 169.09, respectively


#we can also use median as the estimator by doing this:
#from numpy import median
#y = master_data['domestic_ROI_perc']
#x = master_data['release_month']

#ax = sns.barplot(x=x, y=y, data=genre_df_medians, estimator=median).set(title="Median Worldwide ROI in Percentanges for Films by Genre")

#ax.set_xlabel("Genre")
#ax.set_ylabel("Worldwide ROI in Percentages")
# Out:
# Text(0.5, 0, 'Genre')
